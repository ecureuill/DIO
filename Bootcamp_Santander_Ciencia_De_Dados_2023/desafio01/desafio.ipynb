# %% [markdown]
# # ETL
# ## Requirements

# %%
pip install pandas requests Faker

# %% [markdown]
# ## Extracting

# %%
import requests
from datetime import datetime
from faker import Faker


api_url = 'https://jsonplaceholder.typicode.com/todos'

def get_todos():
    response = requests.get(api_url)
    return response.json() if response.status_code == 200 else None

todos = get_todos()

faker = Faker()

for todo in todos:
    createDate = faker.date_time()
    dueDate = faker.date_between(createDate)
    doneDate = faker.date_between(createDate)

    todo['createDate'] = createDate.strftime('%x')
    todo['dueDate'] = dueDate.strftime('%x')

    todo['doneDate'] = doneDate.strftime('%x') if todo['completed'] == True else None

print(todos)
# Out:
# [{'userId': 1, 'id': 1, 'title': 'delectus aut autem', 'completed': False, 'createDate': '02/22/78', 'dueDate': '04/03/95', 'doneDate': None}, {'userId': 1, 'id': 2, 'title': 'quis ut nam facilis et officia qui', 'completed': False, 'createDate': '04/21/07', 'dueDate': '01/19/13', 'doneDate': None}, {'userId': 1, 'id': 3, 'title': 'fugiat veniam minus', 'completed': False, 'createDate': '09/09/05', 'dueDate': '07/03/20', 'doneDate': None}, {'userId': 1, 'id': 4, 'title': 'et porro tempora', 'completed': True, 'createDate': '10/05/18', 'dueDate': '02/04/20', 'doneDate': '08/28/19'}, {'userId': 1, 'id': 5, 'title': 'laboriosam mollitia et enim quasi adipisci quia provident illum', 'completed': False, 'createDate': '12/09/89', 'dueDate': '04/19/12', 'doneDate': None}, {'userId': 1, 'id': 6, 'title': 'qui ullam ratione quibusdam voluptatem quia omnis', 'completed': False, 'createDate': '07/03/70', 'dueDate': '05/16/89', 'doneDate': None}, {'userId': 1, 'id': 7, 'title': 'illo expedita consequatur quia in', 'completed': False, 'createDate': '02/16/20', 'dueDate': '05/01/20', 'doneDate': None}, {'userId': 1, 'id': 8, 'title': 'quo adipisci enim quam ut ab', 'completed': True, 'createDate': '06/06/04', 'dueDate': '08/19/21', 'doneDate': '09/15/05'}, {'userId': 1, 'id': 9, 'title': 'molestiae perspiciatis ipsa', 'completed': False, 'createDate': '06/25/81', 'dueDate': '06/18/16', 'doneDate': None}, {'userId': 1, 'id': 10, 'title': 'illo est ratione doloremque quia maiores aut', 'completed': True, 'createDate': '07/01/71', 'dueDate': '05/07/74', 'doneDate': '08/28/76'}, {'userId': 1, 'id': 11, 'title': 'vero rerum temporibus dolor', 'completed': True, 'createDate': '10/23/83', 'dueDate': '04/30/23', 'doneDate': '11/21/11'}, {'userId': 1, 'id': 12, 'title': 'ipsa repellendus fugit nisi', 'completed': True, 'createDate': '04/29/19', 'dueDate': '03/11/22', 'doneDate': '01/26/22'}, {'userId': 1, 'id': 13, 'title': 'et doloremque nulla', 'completed': False, 'createDate': '09/03/84', 'dueDate': '05/21/93', 'doneDate': None}, {'userId': 1, 'id': 14, 'title': 'repellendus sunt dolores architecto voluptatum', 'completed': True, 'createDate': '12/20/16', 'dueDate': '09/25/20', 'doneDate': '05/01/20'}, {'userId': 1, 'id': 15, 'title': 'ab voluptatum amet voluptas', 'completed': True, 'createDate': '10/11/83', 'dueDate': '06/12/11', 'doneDate': '02/16/12'}, {'userId': 1, 'id': 16, 'title': 'accusamus eos facilis sint et aut voluptatem', 'completed': True, 'createDate': '01/18/08', 'dueDate': '10/31/14', 'doneDate': '01/09/23'}, {'userId': 1, 'id': 17, 'title': 'quo laboriosam deleniti aut qui', 'completed': True, 'createDate': '11/06/12', 'dueDate': '10/28/20', 'doneDate': '01/18/19'}, {'userId': 1, 'id': 18, 'title': 'dolorum est consequatur ea mollitia in culpa', 'completed': False, 'createDate': '05/18/80', 'dueDate': '03/17/02', 'doneDate': None}, {'userId': 1, 'id': 19, 'title': 'molestiae ipsa aut voluptatibus pariatur dolor nihil', 'completed': True, 'createDate': '11/11/88', 'dueDate': '05/30/16', 'doneDate': '12/13/06'}, {'userId': 1, 'id': 20, 'title': 'ullam nobis libero sapiente ad optio sint', 'completed': True, 'createDate': '09/21/91', 'dueDate': '11/14/04', 'doneDate': '04/20/23'}, {'userId': 2, 'id': 21, 'title': 'suscipit repellat esse quibusdam voluptatem incidunt', 'completed': False, 'createDate': '08/03/08', 'dueDate': '01/24/20', 'doneDate': None}, {'userId': 2, 'id': 22, 'title': 'distinctio vitae autem nihil ut molestias quo', 'completed': True, 'createDate': '04/27/08', 'dueDate': '02/10/16', 'doneDate': '08/22/17'}, {'userId': 2, 'id': 23, 'title': 'et itaque necessitatibus maxime molestiae qui quas velit', 'completed': False, 'createDate': '08/01/80', 'dueDate': '06/28/93', 'doneDate': None}, {'userId': 2, 'id': 24, 'title': 'adipisci non ad dicta qui amet quaerat doloribus ea', 'completed': False, 'createDate': '11/08/08', 'dueDate': '10/26/14', 'doneDate': None}, {'userId': 2, 'id': 25, 'title': 'voluptas quo tenetur  ...

# %% [markdown]
# ## Transforming

# %%
import pandas as pd
df = pd.DataFrame(todos)

# Análise de padrões de uso
print("Total de tarefas: ", len(df))
print("Total de tarefas concluídas: ", df['completed'].sum())

# Análise de desempenho
df['doneDate'] = pd.to_datetime(df['doneDate'])
df['dueDate'] = pd.to_datetime(df['dueDate'])
df['delay'] = df['doneDate'] - df['dueDate']
avg_delay = df['delay'].mean()

if avg_delay.days < 0:
    print("As tarefas são concluídas em média", abs(avg_delay.days), "dias antes do prazo.")
else:
    print("As tarefas são concluídas em média", avg_delay.days, "dias de atraso.")

# Análise de produtividade
df['createDate'] = pd.to_datetime(df['createDate'])
df['completionTime'] = df['doneDate'] - df['createDate']
avg_completionTime = df['completionTime'].mean()

print("Tempo médio para conclusão de uma tarefa: ", avg_completionTime)
# Out:
# Total de tarefas:  200
# Total de tarefas concluídas:  90
# As tarefas são concluídas em média 296 dias de atraso.
# Tempo médio para conclusão de uma tarefa:  2120 days 10:56:00
# /tmp/ipykernel_151517/4143027188.py:9: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['doneDate'] = pd.to_datetime(df['doneDate'])
# /tmp/ipykernel_151517/4143027188.py:10: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['dueDate'] = pd.to_datetime(df['dueDate'])
# /tmp/ipykernel_151517/4143027188.py:20: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['createDate'] = pd.to_datetime(df['createDate'])

# %% [markdown]
# ## Loading

# %%
df.to_csv('todos_data.csv', index=False)
